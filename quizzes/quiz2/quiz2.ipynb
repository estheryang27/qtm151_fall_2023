# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your Emory code below

# %%
# Write your answer here
Name = "Esther Yang"
ID = 2487073
print(Name)
print(ID)
# Out:
# Esther Yang
# 2487073

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes and Google
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"
#
# **By printing the message, you acknowledge that you will abide by Emory's code of conduct.**

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code

fifa_data = pd.read_csv("data_quiz/fifa23_players_basic.csv")
fifa_data
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 0                Left                 4            4
# 1               Right                 4            4
# 2               Right                 4            4
# 3               Right                 5            4
# 4               Right                 4            5
# ...               ...               ...          ...
# 18534           Right                 3            2
# 18535           Right                 3            2
# 18536           Right                 3            2
# 18537           Right                 3            2
# 18538            Left                 3            2
#
#        International Reputation National Team Name  \
# 0                             5          Argentina
# 1                             4             France
# 2                             5             Poland
# 3                             4            Belgium
# 4                             4             France
# ...                         ...                ...
# 18534                         1                  -
# 18535                         1                  -
# 18536                         1                  -
# 18537                         1                  -
# 18538                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 0                              10                 Low                 Low
# 1                              19              Medium              Medium
# 2                               9                High              Medium
# 3                               7                High                High
# 4                              10                High                 Low
# ...                           ...                 ...                 ...
# 18534                           -              Medium              Medium
# 18535                           -              Medium              Medium
# 18536                           -                High              Medium
# 18537                           -              Medium              Medium
# 18538                           -              Medium              Medium
#
# [18539 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "overall"
# - If "overall < 85", status = "Regular Player"
# - If "overall >= 85", status = "Top Player"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Overall" in the dataset <br>
# (be carefeful to write the "O" capitalized)
# - Create a new variable called "top_players" <br>
# to assign each player to the correct status
#
# HINT: Use the ".apply()" function

# %%
# Write your own code

# Step 1
def player_status(overall):
    if overall < 85:
        status = "Regular Player"
    else:
        status = "Top Player"
    return status

# Step 2
fifa_data['top_players'] = fifa_data['Overall'].apply(player_status)

#confirm the new variable
fifa_data
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 18534                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate     top_players
# 0                     Low                 Low      Top Player
# 1                  Medium              Medium      Top Player
# 2                    High              Medium      Top Player
# 3                    High                High      Top Player
# 4                    High                 Low      Top Player
# ...                   ...                 ...             ...
# 18534              Medium              Medium  Regular Player
# 18535              Medium              Medium  Regular Player
# 18536                High              Medium  Regular Player
# 18537              Medium              Medium  Regular Player
# 18538              Medium              Medium  Regular Player
#
# [18539 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Wage(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 9) <br>
# Reference the column as ``` `Wage(in Euro)`    ``` inside .query()

# %%
# Write your own code

mean_wage = fifa_data['Value(in Euro)'].mean()

above_mean_wage_players = fifa_data.query('`Value(in Euro)` > @mean_wage')

# to confirm
above_mean_wage_players
# Out:
#             Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0           L. Messi        Lionel Messi       91         91        54000000
# 1         K. Benzema       Karim Benzema       91         91        64000000
# 2     R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3       K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4          K. Mbappé       Kylian Mbappé       91         95       190500000
# ...              ...                 ...      ...        ...             ...
# 7066       F. Rieder       Fabian Rieder       68         83         2900000
# 7071     J. Bakayoko      Johan Bakayoko       68         85         3100000
# 7090        M. Arezo        Matías Arezo       68         81         2900000
# 7096       Y. Kallon        Yayah Kallon       68         82         3000000
# 7168        M. Soulé        Matías Soulé       68         85         3100000
#
#      Positions Played Best Position   Nationality  \
# 0                  RW           CAM     Argentina
# 1               CF,ST            CF        France
# 2                  ST            ST        Poland
# 3              CM,CAM            CM       Belgium
# 4               ST,LW            ST        France
# ...               ...           ...           ...
# 7066           CAM,CM           CAM   Switzerland
# 7071               RW            LM       Belgium
# 7090           ST,CAM            ST       Uruguay
# 7096         RM,RW,CF            ST  Sierra Leone
# 7168               RW            LM     Argentina
#
#                                             Image Link  Age  ...  \
# 0     https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1     https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2     https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3     https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4     https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                ...  ...  ...
# 7066  https://cdn.sofifa.net/players/259/306/23_60.png   20  ...
# 7071  https://cdn.sofifa.net/players/265/450/23_60.png   19  ...
# 7090  https://cdn.sofifa.net/players/254/653/23_60.png   19  ...
# 7096  https://cdn.sofifa.net/players/262/333/23_60.png   21  ...
# 7168  https://cdn.sofifa.net/players/265/695/23_60.png   19  ...
#
#       Weak Foot Rating  Skill Moves  International Reputation  \
# 0                    4            4                         5
# 1                    4            4                         4
# 2                    4            4                         5
# 3                    5            4                         4
# 4                    4            5                         4
# ...                ...          ...                       ...
# 7066                 3            2                         1
# 7071                 3            3                         1
# 7090                 3            4                         1
# 7096                 2            3                         1
# 7168                 4            4                         1
#
#       National Team Name             National Team Image Link  \
# 0              Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                 France  https://cdn.sofifa.net/flags/fr.png
# 2                 Poland  https://cdn.sofifa.net/flags/pl.png
# 3                Belgium  https://cdn.sofifa.net/flags/be.png
# 4                 France  https://cdn.sofifa.net/flags/fr.png
# ...                  ...                                  ...
# 7066                   -  https://cdn.sofifa.net/flags/ch.png
# 7071                   -  https://cdn.sofifa.net/flags/be.png
# 7090                   -  https://cdn.sofifa.net/flags/uy.png
# 7096                   -                                    -
# 7168                   -  https://cdn.sofifa.net/flags/ar.png
#
#       National Team Position  National Team Jersey Number Attacking Work Rate  \
# 0                         RW                           10                 Low
# 1                         ST                           19              Medium
# 2                         ST                            9                High
# 3                         RF                            7                High
# 4                         ST                           10                High
# ...                      ...                          ...                 ...
# 7066                       -                            -                High
# 7071                       -                            -                High
# 7090                       -                            -                High
# 7096                       -                            -                High
# 7168                       -                            -                High
#
#      Defensive Work Rate     top_players
# 0                    Low      Top Player
# 1                 Medium      Top Player
# 2                 Medium      Top Player
# 3                   High      Top Player
# 4                    Low      Top Player
# ...                  ...             ...
# 7066              Medium  Regular Player
# 7071              Medium  Regular Player
# 7090              Medium  Regular Player
# 7096                 Low  Regular Player
# 7168              Medium  Regular Player
#
# [3216 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players
# - Print their age

# %%
# Write your own code

sorted_by_age = fifa_data.sort_values(by='Age', ascending=True)

youngest_5_players = sorted_by_age.iloc[:5]

print(youngest_5_players['Age'])
# Out:
# 17956    16
# 18014    16
# 16084    16
# 11481    16
# 17591    16
# Name: Age, dtype: int64

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with four inputs $f(y,x,b0,b1)$
#
# <font size = "3">
#
# $\qquad e2 = (y - b_0 - b_1 * x)^2$
#
# - The function should return the mean of e2
# - This is the mean-square error (mse)
# - Call the function "fn_mse"
# - Let $y$ be the column "Potential"
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 80, b_1 = 0.4)$ or <br>
# $\qquad (b_0 = 80, b_1 =-0.3)$ or <br>
# $\qquad (b_0 = 80, b_1 = -0.5)$ <br>
# produce the lowest value of mse?
# - Print your results

# %%
# Write your own code


# Define the function
def fn_mse(y, x, b0, b1):
    e2 = (y - b0 - b1 * x) ** 2
    mse = e2.mean()
    return mse

# Extracting columns
y = fifa_data['Potential']
x = fifa_data['Age']

# Calculating MSE
mse_1 = fn_mse(y, x, 80, 0.4)
mse_2 = fn_mse(y, x, 80, -0.3)
mse_3 = fn_mse(y, x, 80, -0.5)

# Print results
print(f"MSE for b0 = 80 and b1 = 0.4: {mse_1}")
print(f"MSE for b0 = 80 and b1 = -0.3: {mse_2}")
print(f"MSE for b0 = 80 and b1 = -0.5: {mse_3}")

# which combination produces the lowest MSE
if mse_1 < mse_2 and mse_1 < mse_3:
    print("MSE for (b0 = 80, b1 = 0.4) produces the lowest value of mse.")
elif mse_2 < mse_1 and mse_2 < mse_3:
    print("MSE for (b0 = 80, b1 = -0.3) produces the lowest value of mse.")
else:
    print("MSE for (b0 = 80, b1 = -0.5) produces the lowest value of mse.")
# Out:
# MSE for b0 = 80 and b1 = 0.4: 412.1016840174767
# MSE for b0 = 80 and b1 = -0.3: 37.72189870003776
# MSE for b0 = 80 and b1 = -0.5: 49.43713253142025
# MSE for (b0 = 80, b1 = -0.3) produces the lowest value of mse.

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Define a random seed that equals 42
#
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" or "1" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code

list_status = [0, 1]
list_prob = [0.5, 0.5]

# number of rows
n = len(fifa_data)

np.random.seed(42)

# np.random.choice
fifa_data['status'] = np.random.choice(list_status,
                                        size=n, 
                                        p=list_prob)

# using .query to subset
data0 = fifa_data.query('status == 0')
data1 = fifa_data.query('status == 1')

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display the distribution of "Age" for "data0" and "data1"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups
#
# - Provide a short interpretation of the graph using the information from the Note

# %%
# Write your own code

# alpha option
plt.figure()
plt.hist(data0['Age'], alpha=0.5, label='data0')
plt.hist(data1['Age'], alpha=0.5, label='data1')

# legend, axes, title
plt.legend(loc='upper right')
plt.title('Distribution of Age for data0 and data1')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Interpretation of the graph:
#
#
# From the histogram above, we can see that the histograms of both groups overlap significantly, and that the distributions of age in both data0 and data1 are very similar. The overlap and similarity are good signs, they indicate that our random assignment was effective in producing two groups with comparable age distributions. Therefore, any differences we might observe in other variables between these two groups would likely not be due to differences in their age distributions.
